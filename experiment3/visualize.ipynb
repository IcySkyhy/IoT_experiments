# %%
# !pip3 install graphviz
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# WARNING: You are using pip version 19.1, however version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# 将`graph`的内容替换成`batadv-vis`命令的输出：

# %%
from graphviz import Source
graph = """
digraph {
        subgraph "cluster_dc:a6:32:1d:50:ca" {
                "dc:a6:32:1d:50:ca"
        }
        "dc:a6:32:1d:50:ca" -> "dc:a6:32:25:bb:b2" [label="1.016"]
        "dc:a6:32:1d:50:ca" -> "dc:a6:32:1d:4f:2e" [label="1.000"]
        "dc:a6:32:1d:50:ca" -> "7e:55:c8:12:7f:c6" [label="TT"]
        "dc:a6:32:1d:50:ca" -> "7e:55:c8:12:7f:c6" [label="TT"]
        subgraph "cluster_dc:a6:32:25:bb:b2" {
                "dc:a6:32:25:bb:b2"
        }
        "dc:a6:32:25:bb:b2" -> "dc:a6:32:1d:50:ca" [label="1.016"]
        "dc:a6:32:25:bb:b2" -> "dc:a6:32:1d:4f:2e" [label="1.000"]
        "dc:a6:32:25:bb:b2" -> "b2:db:ed:58:13:3e" [label="TT"]
        "dc:a6:32:25:bb:b2" -> "b2:db:ed:58:13:3e" [label="TT"]
}
"""
s = Source(graph, filename="network.gv", format="png")
s.render()
# Out:
# 'network.gv.png'

# %%
from IPython.display import Image
Image(filename='network.gv.png')
